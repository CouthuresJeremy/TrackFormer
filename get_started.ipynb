# %% [markdown]
# ##### Copyright 2019 The TensorFlow Authors.

# %%
#@title Licensed under the Apache License, Version 2.0 (the "License");
# you may not use this file except in compliance with the License.
# You may obtain a copy of the License at
#
# https://www.apache.org/licenses/LICENSE-2.0
#
# Unless required by applicable law or agreed to in writing, software
# distributed under the License is distributed on an "AS IS" BASIS,
# WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# See the License for the specific language governing permissions and
# limitations under the License.

# %% [markdown]
# # Get started with TensorBoard
#
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://www.tensorflow.org/tensorboard/get_started"><img src="https://www.tensorflow.org/images/tf_logo_32px.png" />View on TensorFlow.org</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/github/tensorflow/tensorboard/blob/master/docs/get_started.ipynb"><img src="https://www.tensorflow.org/images/colab_logo_32px.png" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/tensorflow/tensorboard/blob/master/docs/get_started.ipynb"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
#   <td>
#     <a href="https://storage.googleapis.com/tensorflow_docs/tensorboard/docs/get_started.ipynb"><img src="https://www.tensorflow.org/images/download_logo_32px.png" />Download notebook</a>
#   </td>
# </table>

# %% [markdown]
# In machine learning, to improve something you often need to be able to measure it. TensorBoard is a tool for providing the measurements and visualizations needed during the machine learning workflow. It enables tracking experiment metrics like loss and accuracy, visualizing the model graph, projecting embeddings to a lower dimensional space, and much more.
#
# This quickstart will show how to quickly get started with TensorBoard. The remaining guides in this website provide more details on specific capabilities, many of which are not included here.

# %%
# Load the TensorBoard notebook extension
# %load_ext tensorboard

# %%
# import tensorflow as tf
# import datetime

# %%
# # Clear any logs from previous runs
# !rm -rf ./logs/

# %% [markdown]
# Using the [MNIST](https://en.wikipedia.org/wiki/MNIST_database) dataset as the example, normalize the data and write a function that creates a simple Keras model for classifying the images into 10 classes.

# %%
# mnist = tf.keras.datasets.mnist

# (x_train, y_train),(x_test, y_test) = mnist.load_data()
# x_train, x_test = x_train / 255.0, x_test / 255.0

# def create_model():
#   return tf.keras.models.Sequential([
#     tf.keras.layers.Input(shape=(28, 28), name='layers_input'),
#     tf.keras.layers.Flatten(name='layers_flatten'),
#     tf.keras.layers.Dense(512, activation='relu', name='layers_dense'),
#     tf.keras.layers.Dropout(0.2, name='layers_dropout'),
#     tf.keras.layers.Dense(10, activation='softmax', name='layers_dense_2')
#   ])
# Out:
# ...
# 11493376/11490434 [==============================] - 0s 0us/step

# %% [markdown]
# ## Using TensorBoard with Keras Model.fit()

# %% [markdown]
# When training with Keras's [Model.fit()](https://www.tensorflow.org/api_docs/python/tf/keras/models/Model#fit), adding the `tf.keras.callbacks.TensorBoard` callback ensures that logs are created and stored. Additionally, enable histogram computation every epoch with `histogram_freq=1` (this is off by default)
#
# Place the logs in a timestamped subdirectory to allow easy selection of different training runs.

# %%
# model = create_model()
# model.compile(optimizer='adam',
#               loss='sparse_categorical_crossentropy',
#               metrics=['accuracy'])

# log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
# tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

# model.fit(x=x_train, 
#           y=y_train, 
#           epochs=5, 
#           validation_data=(x_test, y_test), 
#           callbacks=[tensorboard_callback])
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 15s 246us/sample - loss: 0.2217 - accuracy: 0.9343 - val_loss: 0.1019 - val_accuracy: 0.9685
# Epoch 2/5
# 60000/60000 [==============================] - 14s 229us/sample - loss: 0.0975 - accuracy: 0.9698 - val_loss: 0.0787 - val_accuracy: 0.9758
# Epoch 3/5
# 60000/60000 [==============================] - 14s 231us/sample - loss: 0.0718 - accuracy: 0.9771 - val_loss: 0.0698 - val_accuracy: 0.9781
# Epoch 4/5
# 60000/60000 [==============================] - 14s 227us/sample - loss: 0.0540 - accuracy: 0.9820 - val_loss: 0.0685 - val_accuracy: 0.9795
# Epoch 5/5
# 60000/60000 [==============================] - 14s 228us/sample - loss: 0.0433 - accuracy: 0.9862 - val_loss: 0.0623 - val_accuracy: 0.9823

# %% [markdown]
# Start TensorBoard through the command line or within a notebook experience. The two interfaces are generally the same. In notebooks, use the `%tensorboard` line magic. On the command line, run the same command without "%".

# %%
# !kill 202412
# Out:
# /bin/bash: ligne 1 : kill: (202412) - Aucun processus ayant ce numéro

# %%
# %tensorboard --logdir Models/TrackML/version_315
# Out:
# Reusing TensorBoard on port 6006 (pid 23620), started 0:00:48 ago. (Use '!kill 23620' to kill it.)
#       <iframe id="tensorboard-frame-ac07b426fad07997" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-ac07b426fad07997");
#           const url = new URL("http://localhost");
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# %tensorboard --logdir Models/TrackML
# Out:
#       <iframe id="tensorboard-frame-f3089809b1c94965" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-f3089809b1c94965");
#           const url = new URL("/", window.location);
#           const port = 6007;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# %tensorboard --logdir ~/Bureau/HashingWork/athena/TrackParameters/TrackFormer/Models/TrackML/lightning_logs/version_431/
# Out:
# Reusing TensorBoard on port 6008 (pid 23707), started 0:00:38 ago. (Use '!kill 23707' to kill it.)
#       <iframe id="tensorboard-frame-7b0c995cde17571d" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-7b0c995cde17571d");
#           const url = new URL("http://localhost");
#           const port = 6008;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# %tensorboard --logdir ~/Bureau/HashingWork/athena/TrackParameters/TrackFormer/Models/TrackML/lightning_logs/version_433/
# Out:
# Reusing TensorBoard on port 6009 (pid 23758), started 0:00:31 ago. (Use '!kill 23758' to kill it.)
#       <iframe id="tensorboard-frame-35c400d9ec3ba947" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-35c400d9ec3ba947");
#           const url = new URL("http://localhost");
#           const port = 6009;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# %tensorboard --logdir ~/Bureau/HashingWork/athena/TrackParameters/TrackFormer/Models/TrackML/lightning_logs/version_432/
# Out:
# Reusing TensorBoard on port 6010 (pid 23814), started 0:00:21 ago. (Use '!kill 23814' to kill it.)
#       <iframe id="tensorboard-frame-45a5c38e888a2b74" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-45a5c38e888a2b74");
#           const url = new URL("http://localhost");
#           const port = 6010;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# %tensorboard --logdir ~/Bureau/HashingWork/athena/TrackParameters/TrackFormer/Models/TrackML/lightning_logs/version_437/
# Out:
# Reusing TensorBoard on port 6011 (pid 23865), started 0:02:11 ago. (Use '!kill 23865' to kill it.)
#       <iframe id="tensorboard-frame-b933af0bc5576dec" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-b933af0bc5576dec");
#           const url = new URL("http://localhost");
#           const port = 6011;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# !kill 19137

# %%
# %tensorboard --logdir ~/Bureau/HashingWork/athena/TrackParameters/TrackFormer/Models/TrackML/lightning_logs/version_440/
# Out:
# Reusing TensorBoard on port 6012 (pid 23920), started 0:02:04 ago. (Use '!kill 23920' to kill it.)
#       <iframe id="tensorboard-frame-dd4ffdce25968f7" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-dd4ffdce25968f7");
#           const url = new URL("http://localhost");
#           const port = 6012;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# %tensorboard --port 6007 --logdir ~/Bureau/HashingWork/athena/TrackParameters/TrackFormer/Models/TrackML/lightning_logs/version_509/
# Out:
# Reusing TensorBoard on port 6007 (pid 326074), started 0:00:04 ago. (Use '!kill 326074' to kill it.)
#       <iframe id="tensorboard-frame-909bb919d0e5611e" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-909bb919d0e5611e");
#           const url = new URL("http://localhost");
#           const port = 6007;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# %tensorboard --port 6006 --logdir ~/Bureau/HashingWork/athena/TrackParameters/TrackFormer/Models/TrackML/lightning_logs/version_506/
# Out:
# Reusing TensorBoard on port 6006 (pid 326192), started 0:00:50 ago. (Use '!kill 326192' to kill it.)
#       <iframe id="tensorboard-frame-2b5b5ac7bea3e229" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-2b5b5ac7bea3e229");
#           const url = new URL("http://localhost");
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# <!-- <img class="tfo-display-only-on-site" src="https://github.com/tensorflow/tensorboard/blob/master/docs/images/quickstart_model_fit.png?raw=1"/> -->

# %%
# %tensorboard --port 6009 --logdir ~/Bureau/HashingWork/athena/TrackParameters/TrackFormer/Models/TrackML/lightning_logs/version_510/
# Out:
# Reusing TensorBoard on port 6009 (pid 326357), started 0:00:33 ago. (Use '!kill 326357' to kill it.)
#       <iframe id="tensorboard-frame-8f309fe7b30584b8" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-8f309fe7b30584b8");
#           const url = new URL("http://localhost");
#           const port = 6009;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# %tensorboard --port 6008 --logdir ~/Bureau/HashingWork/athena/TrackParameters/TrackFormer/Models/TrackML/lightning_logs/version_507/
# Out:
# Reusing TensorBoard on port 6008 (pid 326402), started 0:00:31 ago. (Use '!kill 326402' to kill it.)
#       <iframe id="tensorboard-frame-4c53d1099481ec7d" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-4c53d1099481ec7d");
#           const url = new URL("http://localhost");
#           const port = 6008;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# %tensorboard --logdir ~/Bureau/HashingWork/athena/TrackParameters/TrackFormer/Models/TrackML/lightning_logs/version_559/
# Out:
# Reusing TensorBoard on port 6006 (pid 10934), started 0:00:04 ago. (Use '!kill 10934' to kill it.)
#       <iframe id="tensorboard-frame-50328da75d6a29ff" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-50328da75d6a29ff");
#           const url = new URL("http://localhost");
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# %tensorboard --logdir ~/Bureau/HashingWork/athena/TrackParameters/TrackFormer/Models/TrackML/lightning_logs/version_565/
# Out:
# Reusing TensorBoard on port 6007 (pid 13086), started 0:00:02 ago. (Use '!kill 13086' to kill it.)
#       <iframe id="tensorboard-frame-29aa26ab51592086" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-29aa26ab51592086");
#           const url = new URL("http://localhost");
#           const port = 6007;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# %tensorboard --logdir ~/Bureau/HashingWork/athena/TrackParameters/TrackFormer/Models/TrackML/lightning_logs/version_569/
# Out:
# Reusing TensorBoard on port 6009 (pid 19343), started 0:00:02 ago. (Use '!kill 19343' to kill it.)
#       <iframe id="tensorboard-frame-cbeb21a6fdec018b" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-cbeb21a6fdec018b");
#           const url = new URL("http://localhost");
#           const port = 6009;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# %tensorboard --logdir ~/Bureau/HashingWork/athena/TrackParameters/TrackFormer/Models/TrackML/lightning_logs/version_576/

# %%
# %tensorboard --logdir ~/Bureau/HashingWork/athena/TrackParameters/TrackFormer/Models/ActsODD/lightning_logs/version_69/
# Out:
# Reusing TensorBoard on port 6006 (pid 44061), started 0:00:27 ago. (Use '!kill 44061' to kill it.)
#       <iframe id="tensorboard-frame-717ad77168dbb671" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-717ad77168dbb671");
#           const url = new URL("http://localhost");
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# %tensorboard --logdir ~/Bureau/HashingWork/athena/TrackParameters/TrackFormer/Models/ActsODD/lightning_logs/version_70/
# Out:
# Reusing TensorBoard on port 6007 (pid 45117), started 0:00:13 ago. (Use '!kill 45117' to kill it.)
#       <iframe id="tensorboard-frame-c3378feb6d355e3c" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-c3378feb6d355e3c");
#           const url = new URL("http://localhost");
#           const port = 6007;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# %tensorboard --logdir ~/Bureau/HashingWork/athena/TrackParameters/TrackFormer/Models/ActsODD/lightning_logs/version_62/
# Out:
# Reusing TensorBoard on port 6008 (pid 75279), started 0:00:36 ago. (Use '!kill 75279' to kill it.)
#       <iframe id="tensorboard-frame-5318a0cccfdcd03e" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-5318a0cccfdcd03e");
#           const url = new URL("http://localhost");
#           const port = 6008;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# %tensorboard --logdir ~/Bureau/HashingWork/athena/TrackParameters/TrackFormer/Models/ActsODD/lightning_logs/version_72/
# Out:
# Reusing TensorBoard on port 6006 (pid 17290), started 0:00:09 ago. (Use '!kill 17290' to kill it.)
#       <iframe id="tensorboard-frame-250ad14ded1aac9b" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-250ad14ded1aac9b");
#           const url = new URL("http://localhost");
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# %tensorboard --logdir /home/couthures/Bureau/TrackParameters/TrackFormer/Models/ActsODD/version_72/
# Out:
# Reusing TensorBoard on port 6008 (pid 17484), started 0:00:02 ago. (Use '!kill 17484' to kill it.)
#       <iframe id="tensorboard-frame-1f0b026bf5d54623" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-1f0b026bf5d54623");
#           const url = new URL("http://localhost");
#           const port = 6008;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# %tensorboard --logdir ~/Bureau/HashingWork/athena/TrackParameters/TrackFormer/Models/ActsODD/lightning_logs/version_503/
# Out:
# Reusing TensorBoard on port 6008 (pid 1796698), started 0:00:01 ago. (Use '!kill 1796698' to kill it.)
#       <iframe id="tensorboard-frame-3de66ee21ec19b04" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-3de66ee21ec19b04");
#           const url = new URL("http://localhost");
#           const port = 6008;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# %tensorboard --logdir ~/Bureau/HashingWork/athena/TrackParameters/TrackFormer/Models/ActsODD/lightning_logs/version_479/
# Out:
# Reusing TensorBoard on port 6009 (pid 1873735), started 0:00:02 ago. (Use '!kill 1873735' to kill it.)
#       <iframe id="tensorboard-frame-24d53355af246da8" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-24d53355af246da8");
#           const url = new URL("http://localhost");
#           const port = 6009;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# %tensorboard --logdir ~/Bureau/HashingWork/athena/TrackParameters/TrackFormer/Models/ActsODD/lightning_logs/version_505/
# Out:
# Reusing TensorBoard on port 6010 (pid 2118045), started 0:00:03 ago. (Use '!kill 2118045' to kill it.)
#       <iframe id="tensorboard-frame-4a3a86ed365ea4c0" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-4a3a86ed365ea4c0");
#           const url = new URL("http://localhost");
#           const port = 6010;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# %tensorboard --logdir ~/Bureau/HashingWork/athena/TrackParameters/TrackFormer/Models/ActsODD/lightning_logs/version_508/
# Out:
# Reusing TensorBoard on port 6011 (pid 2284742), started 0:00:01 ago. (Use '!kill 2284742' to kill it.)
#       <iframe id="tensorboard-frame-ce6d397ed57af0ae" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-ce6d397ed57af0ae");
#           const url = new URL("http://localhost");
#           const port = 6011;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# !kill 2445990
# Out:
# /bin/bash: ligne 1 : kill: (2445990) - Aucun processus ayant ce numéro

# %%
# %tensorboard --logdir ~/Bureau/HashingWork/athena/TrackParameters/TrackFormer/Models/ActsODD/lightning_logs/version_521/
# Out:
# Reusing TensorBoard on port 6006 (pid 10812), started 0:00:18 ago. (Use '!kill 10812' to kill it.)
#       <iframe id="tensorboard-frame-b9181fe1fe1bb1b4" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-b9181fe1fe1bb1b4");
#           const url = new URL("http://localhost");
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# %tensorboard --logdir ~/Bureau/HashingWork/athena/TrackParameters/TrackFormer/Models/ActsODD/lightning_logs/version_524/
# Out:
# Reusing TensorBoard on port 6007 (pid 10965), started 0:00:15 ago. (Use '!kill 10965' to kill it.)
#       <iframe id="tensorboard-frame-146404d7a0b02a48" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-146404d7a0b02a48");
#           const url = new URL("http://localhost");
#           const port = 6007;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# %tensorboard --logdir ~/Bureau/HashingWork/athena/TrackParameters/TrackFormer/Models/ActsODD/lightning_logs/version_525/
# Out:
# Reusing TensorBoard on port 6008 (pid 11078), started 0:00:12 ago. (Use '!kill 11078' to kill it.)
#       <iframe id="tensorboard-frame-3d1e882c8c12b2b1" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-3d1e882c8c12b2b1");
#           const url = new URL("http://localhost");
#           const port = 6008;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# %tensorboard --logdir ~/Bureau/HashingWork/athena/TrackParameters/TrackFormer/Models/ActsODD/lightning_logs/version_514/
# Out:
# Reusing TensorBoard on port 6009 (pid 11203), started 0:00:11 ago. (Use '!kill 11203' to kill it.)
#       <iframe id="tensorboard-frame-3cf4a41dc85ec504" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-3cf4a41dc85ec504");
#           const url = new URL("http://localhost");
#           const port = 6009;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# %tensorboard --logdir ~/Bureau/HashingWork/athena/TrackParameters/TrackFormer/Models/ActsODD/lightning_logs/version_526/
# Out:
# Reusing TensorBoard on port 6010 (pid 11313), started 0:00:08 ago. (Use '!kill 11313' to kill it.)
#       <iframe id="tensorboard-frame-c227e0260ce4a705" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-c227e0260ce4a705");
#           const url = new URL("http://localhost");
#           const port = 6010;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# %tensorboard --logdir ~/Bureau/HashingWork/athena/TrackParameters/TrackFormer/Models/ActsODD/lightning_logs/version_527/
# Out:
# Reusing TensorBoard on port 6011 (pid 11437), started 0:00:05 ago. (Use '!kill 11437' to kill it.)
#       <iframe id="tensorboard-frame-d2d8d5eb41344b29" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-d2d8d5eb41344b29");
#           const url = new URL("http://localhost");
#           const port = 6011;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# %tensorboard --logdir ~/Bureau/HashingWork/athena/TrackParameters/TrackFormer/Models/ActsODD/lightning_logs/version_528/
# Out:
# Reusing TensorBoard on port 6012 (pid 11545), started 0:00:05 ago. (Use '!kill 11545' to kill it.)
#       <iframe id="tensorboard-frame-2a1affbbd17115f9" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-2a1affbbd17115f9");
#           const url = new URL("http://localhost");
#           const port = 6012;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# %tensorboard --logdir ~/Bureau/HashingWork/athena/TrackParameters/TrackFormer/Models/ActsODD/lightning_logs/version_529/
# Out:
# Reusing TensorBoard on port 6013 (pid 14534), started 6:44:23 ago. (Use '!kill 14534' to kill it.)
#       <iframe id="tensorboard-frame-58cb4d4245ee71d5" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-58cb4d4245ee71d5");
#           const url = new URL("http://localhost");
#           const port = 6013;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# A brief overview of the visualizations created in this example and the dashboards (tabs in top navigation bar) where they can be found:
#
# * **Scalars** show how the loss and metrics change with every epoch. You can use them to also track training speed, learning rate, and other scalar values. Scalars can be found in the **Time Series** or **Scalars** dashboards.
# * **Graphs** help you visualize your model. In this case, the Keras graph of layers is shown which can help you ensure it is built correctly. Graphs can be found in the **Graphs** dashboard.
# * **Histograms** and **Distributions** show the distribution of a Tensor over time. This can be useful to visualize weights and biases and verify that they are changing in an expected way. Histograms can be found in the **Time Series** or **Histograms** dashboards. Distributions can be found in the **Distributions** dashboard.
#
# Additional TensorBoard dashboards are automatically enabled when you log other types of data. For example, the Keras TensorBoard callback lets you log images and embeddings as well. You can see what other dashboards are available in TensorBoard by clicking on the "inactive" dropdown towards the top right.

# %% [markdown]
# ## Using TensorBoard with other methods

# %% [markdown]
# When training with methods such as [`tf.GradientTape()`](https://www.tensorflow.org/api_docs/python/tf/GradientTape), use `tf.summary` to log the required information.
#
# Use the same dataset as above, but convert it to `tf.data.Dataset` to take advantage of batching capabilities:

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train))
test_dataset = tf.data.Dataset.from_tensor_slices((x_test, y_test))

train_dataset = train_dataset.shuffle(60000).batch(64)
test_dataset = test_dataset.batch(64)

# %% [markdown]
# The training code follows the [advanced quickstart](https://www.tensorflow.org/tutorials/quickstart/advanced) tutorial, but shows how to log metrics to TensorBoard. Choose loss and optimizer:

# %%
loss_object = tf.keras.losses.SparseCategoricalCrossentropy()
optimizer = tf.keras.optimizers.Adam()

# %% [markdown]
# Create stateful metrics that can be used to accumulate values during training and logged at any point:

# %%
# Define our metrics
train_loss = tf.keras.metrics.Mean('train_loss', dtype=tf.float32)
train_accuracy = tf.keras.metrics.SparseCategoricalAccuracy('train_accuracy')
test_loss = tf.keras.metrics.Mean('test_loss', dtype=tf.float32)
test_accuracy = tf.keras.metrics.SparseCategoricalAccuracy('test_accuracy')

# %% [markdown]
# Define the training and test functions:

# %%
def train_step(model, optimizer, x_train, y_train):
  with tf.GradientTape() as tape:
    predictions = model(x_train, training=True)
    loss = loss_object(y_train, predictions)
  grads = tape.gradient(loss, model.trainable_variables)
  optimizer.apply_gradients(zip(grads, model.trainable_variables))

  train_loss(loss)
  train_accuracy(y_train, predictions)

def test_step(model, x_test, y_test):
  predictions = model(x_test)
  loss = loss_object(y_test, predictions)

  test_loss(loss)
  test_accuracy(y_test, predictions)

# %% [markdown]
# Set up summary writers to write the summaries to disk in a different logs directory:

# %%
current_time = datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
train_log_dir = 'logs/gradient_tape/' + current_time + '/train'
test_log_dir = 'logs/gradient_tape/' + current_time + '/test'
train_summary_writer = tf.summary.create_file_writer(train_log_dir)
test_summary_writer = tf.summary.create_file_writer(test_log_dir)

# %% [markdown]
# Start training. Use `tf.summary.scalar()` to log metrics (loss and accuracy) during training/testing within the scope of the summary writers to write the summaries to disk. You have control over which metrics to log and how often to do it. Other `tf.summary` functions enable logging other types of data.

# %%
model = create_model() # reset our model

EPOCHS = 5

for epoch in range(EPOCHS):
  for (x_train, y_train) in train_dataset:
    train_step(model, optimizer, x_train, y_train)
  with train_summary_writer.as_default():
    tf.summary.scalar('loss', train_loss.result(), step=epoch)
    tf.summary.scalar('accuracy', train_accuracy.result(), step=epoch)

  for (x_test, y_test) in test_dataset:
    test_step(model, x_test, y_test)
  with test_summary_writer.as_default():
    tf.summary.scalar('loss', test_loss.result(), step=epoch)
    tf.summary.scalar('accuracy', test_accuracy.result(), step=epoch)
  
  template = 'Epoch {}, Loss: {}, Accuracy: {}, Test Loss: {}, Test Accuracy: {}'
  print (template.format(epoch+1,
                         train_loss.result(), 
                         train_accuracy.result()*100,
                         test_loss.result(), 
                         test_accuracy.result()*100))

  # Reset metrics every epoch
  train_loss.reset_state()
  test_loss.reset_state()
  train_accuracy.reset_state()
  test_accuracy.reset_state()
# Out:
# Epoch 1, Loss: 0.24321186542510986, Accuracy: 92.84333801269531, Test Loss: 0.13006582856178284, Test Accuracy: 95.9000015258789
# Epoch 2, Loss: 0.10446818172931671, Accuracy: 96.84833526611328, Test Loss: 0.08867532759904861, Test Accuracy: 97.1199951171875
# Epoch 3, Loss: 0.07096975296735764, Accuracy: 97.80166625976562, Test Loss: 0.07875105738639832, Test Accuracy: 97.48999786376953
# Epoch 4, Loss: 0.05380449816584587, Accuracy: 98.34166717529297, Test Loss: 0.07712937891483307, Test Accuracy: 97.56999969482422
# Epoch 5, Loss: 0.041443776339292526, Accuracy: 98.71833038330078, Test Loss: 0.07514958828687668, Test Accuracy: 97.5

# %% [markdown]
# Open TensorBoard again, this time pointing it at the new log directory. We could have also started TensorBoard to monitor training while it progresses.

# %%
# %tensorboard --logdir logs/gradient_tape

# %% [markdown]
# <!-- <img class="tfo-display-only-on-site" src="https://github.com/tensorflow/tensorboard/blob/master/docs/images/quickstart_gradient_tape.png?raw=1"/> -->

# %% [markdown]
# That's it! You have now seen how to use TensorBoard both through the Keras callback and through `tf.summary` for more custom scenarios.
